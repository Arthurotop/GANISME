# %% [markdown]
# # Imports

# %%
import pandas as pd
import bs4
import requests
import re
import time

# %%
from src.scraping import download_art_images

# %% [markdown]
# # Data

# %%
df = pd.read_csv('data/art_catalog.xlsx - catalog.csv')

# %%
df.head(2)
# Out:
#              AUTHOR                        BORN-DIED             TITLE  \
# 0  AACHEN, Hans von  (b. 1552, Köln, d. 1615, Praha)  Venus and Adonis
# 1  AACHEN, Hans von  (b. 1552, Köln, d. 1615, Praha)          Allegory
#
#       DATE                  TECHNIQUE  \
# 0  1574-88  Oil on canvas, 68 x 95 cm
# 1     1598  Oil on copper, 56 x 47 cm
#
#                                          LOCATION  \
# 0  Fogg Art Museum, Harvard University, Cambridge
# 1                         Alte Pinakothek, Munich
#
#                                               URL      FORM          TYPE  \
# 0    https://www.wga.hu/html/a/aachen/adonis.html  painting  mythological
# 1  https://www.wga.hu/html/a/aachen/allegory.html  painting  mythological
#
#    SCHOOL  TIMEFRAME
# 0  German  1601-1650
# 1  German  1601-1650

# %% [markdown]
# ## Scraping images of paintings

# %%
painting_df = df[df['FORM'] == 'painting']

# %%
painting_df.head(2)
# Out:
#              AUTHOR                        BORN-DIED             TITLE  \
# 0  AACHEN, Hans von  (b. 1552, Köln, d. 1615, Praha)  Venus and Adonis
# 1  AACHEN, Hans von  (b. 1552, Köln, d. 1615, Praha)          Allegory
#
#       DATE                  TECHNIQUE  \
# 0  1574-88  Oil on canvas, 68 x 95 cm
# 1     1598  Oil on copper, 56 x 47 cm
#
#                                          LOCATION  \
# 0  Fogg Art Museum, Harvard University, Cambridge
# 1                         Alte Pinakothek, Munich
#
#                                               URL      FORM          TYPE  \
# 0    https://www.wga.hu/html/a/aachen/adonis.html  painting  mythological
# 1  https://www.wga.hu/html/a/aachen/allegory.html  painting  mythological
#
#    SCHOOL  TIMEFRAME
# 0  German  1601-1650
# 1  German  1601-1650

# %%
download_art_images(painting_df)

# %% [markdown]
# ## Happy Tree Friends

# %%
# from src.happy_getter import main

# %%
# main()
